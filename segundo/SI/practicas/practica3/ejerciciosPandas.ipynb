# %% [markdown]
# ### Import pandas

# %%
import pandas as pd

# %% [markdown]
# ### Import csv

# %%
df = pd.read_csv("./bmw.csv")

# %% [markdown]
# ### Ejercicio 1

# %%
df[:10]
# Out:
#        model  year  price transmission  mileage fuelType  tax   mpg  \
# 0   5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1   6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2   5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3   1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4   7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
# 5   5 Series  2016  14900    Automatic    35309   Diesel  125  60.1
# 6   5 Series  2017  16000    Automatic    38538   Diesel  125  60.1
# 7   2 Series  2018  16250       Manual    10401   Petrol  145  52.3
# 8   4 Series  2017  14250       Manual    42668   Diesel   30  62.8
# 9   5 Series  2016  14250    Automatic    36099   Diesel   20  68.9
#
#    engineSize
# 0         2.0
# 1         2.0
# 2         3.0
# 3         1.5
# 4         3.0
# 5         2.0
# 6         2.0
# 7         1.5
# 8         2.0
# 9         2.0

# %% [markdown]
# ### Ejercicio 2

# %%
serie = df["year"]
size = serie.size
tipo = serie.dtype
print("Tipo:",tipo, "; Size:",size)
# Out:
# Tipo: int64 ; Size: 10781

# %% [markdown]
# ### Ejercicio 3

# %%
serie = df["mileage"]
serie[7::7]
# Out:
# 7        10401
# 14       19057
# 21       78957
# 28       96213
# 35       61818
#          ...
# 10752    41500
# 10759    54008
# 10766    54987
# 10773    60372
# 10780    59432
# Name: mileage, Length: 1540, dtype: int64

# %% [markdown]
# ### Ejercicio 4

# %%
serie = df["mileage"]
serie.sample(frac=.4)
# Out:
# 9007    94347
# 6060     6568
# 7880    20671
# 2849    11602
# 8796     4971
#         ...
# 6587     6742
# 3270      105
# 35      61818
# 1866    26965
# 9726    19330
# Name: mileage, Length: 4312, dtype: int64

# %% [markdown]
# ### Ejercicio 5

# %%
serie = df["mileage"]
indices = serie < 20000
serie[indices]
# Out:
# 1        14827
# 7        10401
# 14       19057
# 15       16570
# 39        6522
#          ...
# 10740     3551
# 10741     2784
# 10742     5634
# 10743    13165
# 10755    13955
# Name: mileage, Length: 5610, dtype: int64

# %% [markdown]
# ### Ejercicio 6

# %%
serie = df["mpg"]
pd.Series.sort_values(serie)
# Out:
# 6172       5.5
# 1237       5.5
# 6132       5.5
# 6965       5.5
# 2116       5.5
#          ...
# 7347     470.8
# 5176     470.8
# 10080    470.8
# 8375     470.8
# 9924     470.8
# Name: mpg, Length: 10781, dtype: float64

# %% [markdown]
# ### Ejercicio 7

# %%
serie = df["engineSize"]
media = serie.mean()
desv = serie.std()
minimum = serie.min()
maximum = serie.max()
print(media, desv, minimum, maximum)
# Out:
# 2.1677673685186902 0.5520537772398375 0.0 6.6

# %% [markdown]
# ### Ejercicio 8

# %%
filas,columnas = df.shape
print("Filas:",filas,"Columnas:",columnas)
print("Antepenúltimo registro:")
print(df.iloc[-3])
# Out:
# Filas: 10781 Columnas: 9
# Antepenúltimo registro:
# model            3 Series
# year                 2017
# price               13100
# transmission       Manual
# mileage             25468
# fuelType           Petrol
# tax                   200
# mpg                  42.8
# engineSize            2.0
# Name: 10778, dtype: object

# %% [markdown]
# ### Ejercicio 9

# %%
nuevoDf = df[["mileage","price","mpg"]]
nuevoDf.sample(frac=.2)
# Out:
#        mileage  price   mpg
# 532       8441  21498  48.7
# 9559     87743   8999  72.4
# 8319      9564  24950  60.1
# 6788     19164  15995  55.5
# 3352       103  33850  37.2
# ...        ...    ...   ...
# 10211    18716  13900  65.7
# 241       5000  78000  31.4
# 4511     33546  16498  67.3
# 567      37842  17410  65.7
# 4262     19470  25000  51.4
#
# [2156 rows x 3 columns]

# %% [markdown]
# ### Ejercicio 10

# %%
indices = (df["mileage"]<10000) & (df["mpg"]>40)
df[indices]
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 131     1 Series  2017  14600    Automatic     5615   Petrol  145  58.9
# 148     1 Series  2016  13700       Manual     8719   Petrol  125  52.3
# 153     1 Series  2016  13750    Automatic     8707   Petrol   30  55.5
# 166           X1  2020  31498    Semi-Auto     1560   Diesel  145  60.1
# 167     2 Series  2020  27998       Manual     1580   Petrol  150  43.5
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 10713   3 Series  2020  23899    Automatic     1255   Petrol  150  47.9
# 10739   3 Series  2019  23987    Automatic     1049   Petrol  150  47.9
# 10740   3 Series  2019  23454    Automatic     3551   Petrol  150  47.9
# 10741   3 Series  2019  23599    Automatic     2784   Petrol  145  47.9
# 10742   3 Series  2019  23499    Automatic     5634   Petrol  145  47.9
#
#        engineSize
# 131           1.5
# 148           1.5
# 153           1.5
# 166           2.0
# ...

# %% [markdown]
# ### Ejercicio 11

# %%
dfModificado = df.copy()
mapeo_modelo = {
    " 1 Series": "Serie 1",
    " 2 Series": "Serie 2",
    " 3 Series": "Serie 3",
    " 4 Series": "Serie 4",
    " 5 Series": "Serie 5",
    " 6 Series": "Serie 6",
    " 7 Series": "Serie 7",
    " 8 Series": "Serie 8",
    " 9 Series": "Serie 9"
}

dfModificado['model'] = dfModificado['model'].replace(mapeo_modelo)
dfModificado
# Out:
#          model  year  price transmission  mileage fuelType  tax   mpg  \
# 0      Serie 5  2014  11200    Automatic    67068   Diesel  125  57.6
# 1      Serie 6  2018  27000    Automatic    14827   Petrol  145  42.8
# 2      Serie 5  2016  16000    Automatic    62794   Diesel  160  51.4
# 3      Serie 1  2017  12750    Automatic    26676   Diesel  145  72.4
# 4      Serie 7  2014  14500    Automatic    39554   Diesel  160  50.4
# ...        ...   ...    ...          ...      ...      ...  ...   ...
# 10776       X3  2016  19000    Automatic    40818   Diesel  150  54.3
# 10777  Serie 5  2016  14600    Automatic    42947   Diesel  125  60.1
# 10778  Serie 3  2017  13100       Manual    25468   Petrol  200  42.8
# 10779  Serie 1  2014   9930    Automatic    45000   Diesel   30  64.2
# 10780       X1  2017  15981    Automatic    59432   Diesel  125  57.6
#
#        engineSize
# 0             2.0
# 1             2.0
# 2             3.0
# 3             1.5
# 4             3.0
# ...

# %% [markdown]
# ### Ejercicio 12

# %%
dfNuevo = df.copy()
registro = {
    "model":" 3 Series",
    "year":2023,
    "price" : 22572,
    "transmission" : "Automatic",
    "mileage" : 74120,
    "fuelType" : "Diesel",
    "tax" : 160,
    "mpg" : 58.4,
    "engineSize" : 2.0
}
nuevoReg = pd.DataFrame([registro])
dfNuevo = pd.concat([dfNuevo,nuevoReg], ignore_index=True)
dfNuevo
# Out:
#            model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       5 Series  2014  11200    Automatic    67068   Diesel  125  57.6
# 1       6 Series  2018  27000    Automatic    14827   Petrol  145  42.8
# 2       5 Series  2016  16000    Automatic    62794   Diesel  160  51.4
# 3       1 Series  2017  12750    Automatic    26676   Diesel  145  72.4
# 4       7 Series  2014  14500    Automatic    39554   Diesel  160  50.4
# ...          ...   ...    ...          ...      ...      ...  ...   ...
# 10777   5 Series  2016  14600    Automatic    42947   Diesel  125  60.1
# 10778   3 Series  2017  13100       Manual    25468   Petrol  200  42.8
# 10779   1 Series  2014   9930    Automatic    45000   Diesel   30  64.2
# 10780         X1  2017  15981    Automatic    59432   Diesel  125  57.6
# 10781   3 Series  2023  22572    Automatic    74120   Diesel  160  58.4
#
#        engineSize
# 0             2.0
# 1             2.0
# 2             3.0
# 3             1.5
# ...

# %% [markdown]
# ### Ejercicio 13

# %%
ndarray = df.values
print(ndarray)
type(ndarray)
# Out:
# [[' 5 Series' 2014 11200 ... 125 57.6 2.0]
#  [' 6 Series' 2018 27000 ... 145 42.8 2.0]
#  [' 5 Series' 2016 16000 ... 160 51.4 3.0]
#  ...
#  [' 3 Series' 2017 13100 ... 200 42.8 2.0]
#  [' 1 Series' 2014 9930 ... 30 64.2 2.0]
#  [' X1' 2017 15981 ... 125 57.6 2.0]]
# numpy.ndarray

# %% [markdown]
# ### Ejercicio 14

# %%
import datetime
currentYear = datetime.datetime.now().year
dfNuevo = df.copy()
dfNuevo["mile/year"] = df["mileage"]/(currentYear-df["year"])
dfNuevo["mile/year"]
# Out:
# 0        6706.800000
# 1        2471.166667
# 2        7849.250000
# 3        3810.857143
# 4        3955.400000
#             ...
# 10776    5102.250000
# 10777    5368.375000
# 10778    3638.285714
# 10779    4500.000000
# 10780    8490.285714
# Name: mile/year, Length: 10781, dtype: float64
